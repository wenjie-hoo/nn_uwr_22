# %% [markdown]
# <a href="https://colab.research.google.com/github/wenjie-hoo/nn_uwr_22/blob/main/en2pl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EN2PL
# ### Sequence-to-Sequence translation Model with Attention

# %%
import collections
import itertools
import math
import numpy as np
import pandas as pd
import re
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import Counter
from functools import partial
from pathlib import Path
from google_drive_downloader import GoogleDriveDownloader as gdd
from nltk import wordpunct_tokenize
from nltk.tokenize import word_tokenize
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
from tqdm import tqdm_notebook, tqdm

# %%
# !gdown https://opus.nlpl.eu/download.php?f=CCAligned/v1/moses/en-pl.txt.zip
# Out:
# Downloading...
# From: https://opus.nlpl.eu/download.php?f=CCAligned/v1/moses/en-pl.txt.zip
# To: /content/en-pl.txt.zip
# 100% 1.20G/1.20G [01:09<00:00, 17.2MB/s]

# %%
! unzip en-pl.txt.zip
# Out:
# Archive:  en-pl.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: CCAligned.en-pl.en
#   inflating: CCAligned.en-pl.pl
#   inflating: CCAligned.en-pl.xml

# %%
# ! gdown https://object.pouta.csc.fi/OPUS-100/v1.0/opus-100-corpus-en-pl-v1.0.tar.gz
# Out:
# Downloading...
# From: https://object.pouta.csc.fi/OPUS-100/v1.0/opus-100-corpus-en-pl-v1.0.tar.gz
# To: /content/opus-100-corpus-en-pl-v1.0.tar.gz
# 100% 39.3M/39.3M [00:02<00:00, 13.8MB/s]

# %%
# ! tar -xf /content/opus-100-corpus-en-pl-v1.0.tar.gz

# %%
def parallel_lines(file1_path, file2_path, output_file_path):
    with open(file1_path, 'r') as file1, open(file2_path, 'r') as file2, open(output_file_path, 'w') as output_file:
        for line1, line2 in zip(file1, file2):
            line1 = line1.strip()
            line2 = line2.strip()
            parallel_lines = f"{line1}\t{line2}\n"
            output_file.write(parallel_lines)
# file1_path = './opus-100-corpus/v1.0/supervised/en-pl/opus.en-pl-train.en'
# file2_path = './opus-100-corpus/v1.0/supervised/en-pl/opus.en-pl-train.pl'
file1_path = 'CCAligned.en-pl.en'
file2_path = 'CCAligned.en-pl.pl'
output_file_path = 'en_pl.txt'

parallel_lines(file1_path, file2_path, output_file_path)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def tokenize(text):
    text = str(text).lower()
    tokens = wordpunct_tokenize(text)
    tokens = [token for token in tokens
    if all(char.isalpha() for char in token)]
    return tokens

class EnglishPolishTranslations(Dataset):
    def __init__(self, path, max_vocab):
        self.max_vocab = max_vocab
        self.padding_token = '<PAD>'
        self.start_token = '<SOS>'
        self.end_token = '<EOS>'
        self.unknown_word_token = '<UNK>'
        self.flatten = lambda x: [sublst for lst in x for sublst in lst]

        df = pd.read_csv(path, names=['english', 'polish'], sep='\t')
        self.tokenize_df(df)
        self.rare_tokens(df)
        self.create_token2idx(df)

        df = self.remove_unk(df)
        self.add_start_and_end_to_tokens(df)
        self.tokens_to_indices(df)
    #0en 1pl
    def __getitem__(self, idx):
        pair = self.indices_pairs[idx]
        return pair[0], pair[1]

    def tokenize_df(self, df):
        df['tokens_inputs'] = df.english.apply(tokenize)
        df['tokens_targets'] = df.polish.apply(tokenize)

    def rare_tokens(self, df):
        common_tokens_inputs = self.get_most_common_tokens(df.tokens_inputs.tolist())
        common_tokens_targets = self.get_most_common_tokens(df.tokens_targets.tolist())

        df['tokens_inputs'] = df.tokens_inputs.apply(lambda tokens: [token if token in common_tokens_inputs else self.unknown_word_token for token in tokens])
        df['tokens_targets'] = df.tokens_targets.apply(lambda tokens: [token if token in common_tokens_targets else self.unknown_word_token for token in tokens])

    def get_most_common_tokens(self, tokens_series):
        all_tokens = [token for sublist in tokens_series for token in sublist]
        token_counts = Counter(all_tokens)
        most_common_tokens = {token for token, count in token_counts.most_common(self.max_vocab - 4)}
        return most_common_tokens

    def remove_unk(self, df, threshold=0.99):
        def calculate_ratio(tokens):
            if len(tokens) == 0:
                return False
            count = sum(1 for token in tokens if token != '<UNK>')
            return count / len(tokens) > threshold
        df = df[df['tokens_inputs'].apply(calculate_ratio)]
        df = df[df['tokens_targets'].apply(calculate_ratio)]
        return df

    def create_token2idx(self, df):
      unique_tokens_inputs = set(self.flatten(df.tokens_inputs))
      unique_tokens_targets = set(self.flatten(df.tokens_targets))
      special_tokens = [self.padding_token, self.start_token, self.end_token, self.unknown_word_token,]
      unique_tokens_inputs -= set(special_tokens)
      unique_tokens_targets -= set(special_tokens)
      unique_tokens_inputs = sorted(special_tokens) + sorted(unique_tokens_inputs)
      unique_tokens_targets = sorted(special_tokens) + sorted(unique_tokens_targets)

      self.token2idx_inputs = {token: idx for idx, token in enumerate(unique_tokens_inputs)}
      self.idx2token_inputs = {idx: token for token, idx in self.token2idx_inputs.items()}
      self.token2idx_targets = {token: idx for idx, token in enumerate(unique_tokens_targets)}
      self.idx2token_targets = {idx: token for token, idx in self.token2idx_targets.items()}

    def add_start_and_end_to_tokens(self, df):
        df['tokens_inputs'] = df.tokens_inputs.apply(lambda tokens: [self.start_token] + tokens + [self.end_token])
        df['tokens_targets'] = df.tokens_targets.apply(lambda tokens: [self.start_token] + tokens + [self.end_token])

    def tokens_to_indices(self, df):
        df['indices_inputs'] = df.tokens_inputs.apply(
            lambda tokens: [self.token2idx_inputs[token] for token in tokens])
        df['indices_targets'] = df.tokens_targets.apply(
            lambda tokens: [self.token2idx_targets[token] for token in tokens])
        self.indices_pairs = list(zip(df.indices_inputs, df.indices_targets))

    def __len__(self):
        return len(self.indices_pairs)

# %%
def clean(file_path, output_file_path):
    special_chars_pattern = re.compile(r'[^\w\s]')
    with open(file_path, 'r') as input_file, open(output_file_path, 'w') as output_file:
        for line in input_file:
            line = line.strip()
            line = special_chars_pattern.sub('', line)
            if not line.isdigit() and line:
                output_file.write(line + '\n')

file_path = 'en_pl.txt'
output_file_path = 'en2pl.txt'
clean(file_path, output_file_path)

# %%
# DATA_PATH = './en2pl.txt'

# %%
# not enough ram
# ! split -l 5000000 '--additional-suffix=.txt' en2pl.txt en2pl_
! split -l 500000 '--additional-suffix=.txt' en2pl.txt en2pl_

# %%
DATA_PATH = './en2pl_aa.txt'

# %%
dataset = EnglishPolishTranslations(DATA_PATH, max_vocab=10000)
# Out:
# 272000

# %%
train_size = int(0.999 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# %%
print(test_size)
# Out:
# 272

# %% [markdown]
# ### Collation function and dataloaders

# %%
def collate(batch):
    inputs = [torch.LongTensor(item[0]) for item in batch]
    targets = [torch.LongTensor(item[1]) for item in batch]

    padded_inputs = pad_sequence(inputs, padding_value=dataset.token2idx_targets[dataset.padding_token], batch_first=True)
    padded_targets = pad_sequence(targets, padding_value=dataset.token2idx_targets[dataset.padding_token], batch_first=True)

    lengths = torch.LongTensor([len(x) for x in inputs])
    lengths, permutation = lengths.sort(dim=0, descending=True)

    return padded_inputs[permutation].to(device), padded_targets[permutation].to(device), lengths.to(device)

# %%
batch_size = 512
train_loader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=collate)
test_loader = DataLoader(test_dataset, batch_size=1, collate_fn=collate)

# %% [markdown]
# ## Seq2Seq with Attention
#
# [seq2seq.ipynb](https://github.com/ZeweiChu/PyTorch-Course/blob/master/notebooks/7.seq2seq.ipynb)
#
# [source](https://jalammar.github.io/visualizing-neural-machine-translation-mechanics-of-seq2seq-models-with-attention/)
#
# https://zhuanlan.zhihu.com/p/135970560
#
# https://github.com/wangshusen/DeepLearning/blob/master/Slides/10_Transformer_1.pdf

# %% [markdown]
# #### Define the Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, batch_size):
        super(Encoder, self).__init__()
        self.batch_size = batch_size
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.embedding = nn.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = nn.GRU(self.embedding_dim, self.hidden_size, batch_first=True)

    def forward(self, inputs, lengths):
        embedded = self.embedding(inputs)
        packed = pack_padded_sequence(embedded, lengths, batch_first=True)
        output, hidden = self.gru(packed)
        output, _ = pad_packed_sequence(output)
        return output, hidden

    def init_hidden(self):
        return torch.randn(1, self.batch_size, self.hidden_size).to(device)

# %% [markdown]
# ### Define the Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, decoder_hidden_size, encoder_hidden_size, batch_size):
        super(Decoder, self).__init__()
        self.batch_size = batch_size
        self.encoder_hidden_size = encoder_hidden_size
        self.decoder_hidden_size = decoder_hidden_size
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim

        self.embedding = nn.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = nn.GRU(self.embedding_dim + self.encoder_hidden_size, self.decoder_hidden_size, batch_first=True)
        self.fc = nn.Linear(self.decoder_hidden_size, self.vocab_size)
        #attention weight
        self.W1 = nn.Linear(self.encoder_hidden_size, self.decoder_hidden_size)
        self.W2 = nn.Linear(self.encoder_hidden_size, self.decoder_hidden_size)
        self.V = nn.Linear(self.decoder_hidden_size, 1)

    def forward(self, targets, hidden, encoder_output):
        encoder_output = encoder_output.permute(1, 0, 2)
        hidden_with_time_axis = hidden.permute(1, 0, 2)
        #attention score
        score = torch.tanh(self.W1(encoder_output) + self.W2(hidden_with_time_axis))
        attention_weights = torch.softmax(self.V(score), dim=1)

        context_vector = torch.bmm(attention_weights.permute(0, 2, 1), encoder_output).squeeze(1)
        x = self.embedding(targets)
        x = torch.cat((context_vector.unsqueeze(1), x), dim=-1)

        output, state = self.gru(x, self.init_hidden())
        output = output.view(-1, output.size(2))
        x = self.fc(output)

        return x, state, attention_weights

    def init_hidden(self):
        return torch.randn(1, self.batch_size, self.decoder_hidden_size).to(device)

# %% [markdown]
# ### Define a model that has both an Encoder and Decoder

# %%
criterion = nn.CrossEntropyLoss()

def loss_function(real, pred):
    mask = real.ge(1).float().to(device)
    loss_ = criterion(pred, real) * mask
    return torch.mean(loss_)


class EncoderDecoder(nn.Module):
    def __init__(self, inputs_vocab_size, targets_vocab_size, hidden_size,
                 embedding_dim, batch_size, targets_start_idx, targets_stop_idx):
        super(EncoderDecoder, self).__init__()
        self.batch_size = batch_size
        self.targets_start_idx = targets_start_idx
        self.targets_stop_idx = targets_stop_idx

        self.encoder = Encoder(inputs_vocab_size, embedding_dim,
                               hidden_size, batch_size).to(device)

        self.decoder = Decoder(targets_vocab_size, embedding_dim,
                               hidden_size, hidden_size, batch_size).to(device)

    def predict(self, inputs, lengths):
        self.batch_size = inputs.size(0)
        encoder_output, encoder_hidden = self.encoder(inputs.to(device), lengths,)
        decoder_hidden = encoder_hidden
        decoder_input = torch.LongTensor([[self.targets_start_idx]] * self.batch_size,)
        #output predictions instead of loss
        output = []
        for _ in range(20):
            predictions, decoder_hidden, _ = self.decoder(
                decoder_input.to(device),
                decoder_hidden.to(device),
                encoder_output.to(device),
            )
            prediction = torch.multinomial(F.softmax(predictions, dim=1), 1)
            decoder_input = prediction

            prediction = prediction.item()
            output.append(prediction)

            if prediction == self.targets_stop_idx:
                return output

        return output

    def forward(self, inputs, targets, lengths):
        self.batch_size = inputs.size(0)

        encoder_output, encoder_hidden = self.encoder(inputs.to(device), lengths,)
        decoder_hidden = encoder_hidden

        # Initialize the input of the decoder to be <SOS>
        decoder_input = torch.LongTensor([[self.targets_start_idx]] * self.batch_size,)
        loss = 0
        for timestep in range(1, targets.size(1)):
            predictions, decoder_hidden, _ = self.decoder(
                decoder_input.to(device),
                decoder_hidden.to(device),
                encoder_output.to(device),
            )
            decoder_input = targets[:, timestep].unsqueeze(1)
            loss += loss_function(targets[:, timestep], predictions)

        return loss / targets.size(1)

# %%
model = EncoderDecoder(
    inputs_vocab_size=len(dataset.token2idx_inputs),
    targets_vocab_size=len(dataset.token2idx_targets),
    hidden_size=256,
    embedding_dim=100,
    batch_size=batch_size,
    targets_start_idx=dataset.token2idx_targets[dataset.start_token],
    targets_stop_idx=dataset.token2idx_targets[dataset.end_token],
).to(device)

optimizer = optim.Adam([p for p in model.parameters() if p.requires_grad], lr=0.001)

# %%
model_h = EncoderDecoder(
    inputs_vocab_size=len(dataset.token2idx_inputs),
    targets_vocab_size=len(dataset.token2idx_targets),
    hidden_size=512,
    embedding_dim=200,
    batch_size=batch_size,
    targets_start_idx=dataset.token2idx_targets[dataset.start_token],
    targets_stop_idx=dataset.token2idx_targets[dataset.end_token],
).to(device)

optimizer = optim.Adam([p for p in model_h.parameters() if p.requires_grad], lr=0.01)

# %%
def train(model):
  model.train()
  losses = []
  for epoch in range(10):
      total_loss = total = 0
      progress_bar = tqdm_notebook(train_loader, desc='Training', leave=False)
      for inputs, targets, lengths in progress_bar:
          optimizer.zero_grad()
          loss = model(inputs, targets, lengths.cpu())
          loss.backward()
          losses.append(loss)
          optimizer.step()
          total_loss += loss.item()
          total += targets.size(1)

      train_loss = total_loss / total

      tqdm.write(f'epoch #{epoch + 1:3d}\ttrain_loss: {train_loss:.2e}\n')

# %%
# train(model)

# %%
train(model_h)
# Out:
# <ipython-input-21-cac8feb7f599>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   progress_bar = tqdm_notebook(train_loader, desc='Training', leave=False)
# Training:   0%|          | 0/531 [00:00<?, ?it/s]

# %%
# torch.save(model.state_dict(), 'en2pl.model')

# %%
# model.load_state_dict(torch.load('en2pl.model'))

# %%
model_h.eval()
total_loss = total = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ac5c8c886e6> in <cell line: 1>()
# ----> 1 model.eval()
#       2 total_loss = total = 0
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### BLEU evaluation
# https://aclanthology.org/P02-1040.pdf \
# https://machinelearningmastery.com/calculate-bleu-score-for-text-python/

# %%
def bleu_score(candidate, references, n):
    candidate_ngrams = Counter(zip(*[candidate[i:] for i in range(n)]))
    reference_ngrams = [Counter(zip(*[ref[i:] for i in range(n)])) for ref in references]

    clipped_counts = dict()
    for ngram, count in candidate_ngrams.items():
        clipped_count = 0
        for ref_counts in reference_ngrams:
            clipped_count = max(clipped_count, min(ref_counts[ngram], count))
        clipped_counts[ngram] = clipped_count

    candidate_length = len(candidate)
    reference_length = min([len(ref) for ref in references], key=lambda x: abs(x - candidate_length))

    precision = sum(clipped_counts.values()) / float(candidate_length)
    brevity_penalty = min(1, math.exp(1 - reference_length / float(candidate_length)))

    bleu = brevity_penalty * precision

    return bleu

# %%
candidate_corpus = []
reference_corpus = []
with torch.no_grad():
    for inputs, targets, lengths in test_loader:
        input_tokens = [
            dataset.idx2token_inputs[idx]
            for idx in inputs.cpu()[0].numpy()[1:-1]
        ]
        print('>', ' '.join(input_tokens))
        target_tokens = [
            dataset.idx2token_targets[idx]
            for idx in targets.cpu()[0].numpy()[1:-1]
        ]

        target_sentences = [[''.join(tokens) for tokens in target_tokens]]
        print('=', ' '.join(target_tokens))
        reference_corpus.append([' '.join(target_tokens)])
        # Forward pass
        outputs = model.predict(inputs, lengths.cpu())
        output_tokens = [
            dataset.idx2token_targets[idx]
            for idx in outputs[:-1]
        ]
        predicted_sentences = [''.join(tokens) for tokens in output_tokens]
        candidate_corpus.append(' '.join(output_tokens))
        # print(predicted_sentences)
        print(' '.join(output_tokens))
        score = bleu_score(predicted_sentences, target_sentences , n=1)
        print(score)
        print()
# Out:
# > assessment
# = ocena środków pomocy
# ocena
# 0.1353352832366127
#
# > thank you randy
# = dziękuję randy
# dziękuję randy
# 1.0
#
# > thats something i could never adapt to
# = widzisz do tego nie mógłbym się nigdy dostosować
# to nie mogę jej nie mogę
# 0.11942188509563154
#
# > its not me you should be arresting mr holmes
# = chodź szybko to nie mnie powinien pan aresztować panie holmes
# to nie ma już tracę możliwości
# 0.17113903967753066
#
# > john taylor
# = john taylor
# john taylor
# 1.0
#
# > he got out
# = uciekł
# wyszedł
# 0.0
#
# > stay with me
# = zostań ze mną
# zostań ze mną
# 1.0
#
# > if you were to drop the charges
# = gdybyś mógł wycofać zarzuty
# my także przestaniesz powiązanych
# 0.0
#
# > how could you do this to me
# = jak mogłaś mi to zrobić
# ok jak to się ze mną
# 0.3333333333333333
#
# > i already gave you people my dna
# = już dałem wam moje dna
# już dałam ci ludzie może zająć stare dna
# 0.25
#
# > michelle was a beautiful woman
# = michelle była piękną kobietą
# michelle było piękny kobieta
# 0.25
#
# > the hall is free
# = akurat sala jest wolna
# brakuje musi być tutaj
# 0.0
#
# > i know because ive seen it before
# = wiem ponieważ widziałam to wcześniej
# próbowałam bo to zrobiłem
# 0.19470019576785122
#
# > i i just wanted to check and see if you still need me peg
# = dlaczego dzwonię
# chciałem tylko sprawdzić czy rzeczywiście musisz mi potrzebny
# 0.0
#
# > i think there was a telephone call for you inside
# = chyba ktoś do ciebie dzwonił
# myślę że tak więc już dzwonić po was
# 0.0
#
# > i should open up your ears hmm
# = powinienem odciąć ci uszy
# powinnam otworzyć swoje uszy
# 0.25
#
# > fine
# = dobrze
# w porządku
# 0.0
#
# > it takes about as long as that
# = to mniej więcej tyle samo
# jakaś żona a ile już taki jak i tak
# 0.0
#
# > everybody has the same amount
# = każdy ma go tyle samo
# wszyscy co mówią
# 0.0
#
# > yes
# = tak
# tak
# 1.0
#
# > to make sure we ended together
# = musiałem być pewny że skończymy to razem
# nad tym razem
# 0.08786571270524224
#
# > get your kit out of the car
# = weź sprzęt z samochodu
# weź głęboki krok z stóp
# 0.4
#
# > having regard to the report of the committee on budgetary control
# = uwzględniając sprawozdanie komisji kontroli budżetowej
# uwzględniając sprawozdanie użycia agencji państw trzecich
# 0.3333333333333333
#
# > set you up
# = na jakie spotkanie
# marty
# 0.0
#
# > its okay
# = w porządku
# wszystko w porządku
# 0.6666666666666666
#
# > tel
# = tel
# tel
# 1.0
#
# > um i think
# = w
# nie piękna
# 0.0
#
# > hang on
# = poczekaj
# czekaj
# 0.0
#
# > dismissed
# = może pani odejść
# idź
# 0.0
#
# > havent you noticed
# = nie zauważył ojciec
# nie zauważyłeś
# 0.3032653298563167
#
# > now hes heading slowly towards the cape
# = teraz kieruje się wzdłuż plaży
# uspokój się co pod minut
# 0.2
#
# > establishing the standard import values for determining the entry price of certain fruit and vegetables
# = ustanawiające standardowe wartości w przywozie dla ustalania ceny wejścia niektórych owoców i warzyw
# ustanawiające standardowe wartości celne w przywozie dla ustalania ceny wejścia niektórych owoców i warzyw
# 0.9285714285714286
#
# > you know hell just take the green
# = proszę dać mu słodki zielony
# właśnie straciłeś green
# 0.0
#
# > you didnt hear it from me
# = nie słyszałaś tego ode mnie
# nie słyszałeś to ode mnie
# 0.6
#
# > article
# = artykuł
# artykuł
# 1.0
#
# > hi there
# = cześć
# cześć
# 1.0
#
# > you didnt kill your family did you
# = nie zabiłeś swojej rodziny co
# nikogo nie zabiłaś nikogo rodzinie
# 0.2
#
# > please just do it for me
# = proszę zrób to dla mnie
# po prostu sobie dla mnie zrób
# 0.5
#
# > he did
# = tak
# on zrobił
# 0.0
#
# > what now
# = co teraz
# co teraz
# 1.0
#
# > why didnt you tell me that in the first place
# = dlaczego mi wcześniej o tym nie powiedziałeś
# czemu mi nie żebyś wiedział o nim właśnie stąd
# 0.3333333333333333
#
# > industrial policy needs to have an infrastructure
# = przemysł wymaga infrastruktury
# w związku musi mieć broni
# 0.0
#
# > tell us what you know
# = mów co wiesz
# powiedz to co wiesz o tym znasz
# 0.2857142857142857
#
# > and if he does even if i do get you out of there somehow alive youre going to go away for murder
# = jeśli umrze a mnie jakoś uda się ciebie wyciągnąć stamtąd żywego pójdziesz siedzieć za morderstwo
# jeśli też nie poznam jeśli chcesz mieszkał przy sobie problem pułkowniku zabiję ją zabić
# 0.06650448426457306
#
# > sweetie can i help you
# = skarbie mogę ci w czymś pomóc nie
# kochanie możemy zrobić w porządku
# 0.13406400920712788
#
# > where did they go
# = gdzie oni to biorą co się dzieje
# gdzie jadą
# 0.0410424993119494
#
# > i dont
# = nie nie sądzę
# to nie
# 0.3032653298563167
#
# > its good to see you
# = miło było
# miło was widzieć
# 0.3333333333333333
#
# > no no its gotta be more like this
# = posłuchaj
# ma o to być
# 0.0
#
# > no thanks
# = nie dziękuję
# nie dziękuję
# 1.0
#
# > stop youre going to hurt yourself
# = zrobisz sobie krzywdę
# co umieszcza się gdzieś sobie wyobrażasz co się
# 0.125
#
# > hey walt um
# = hej walt um
# cześć walt w
# 0.3333333333333333
#
# > yeah i do
# = tak wiem
# tak zrobię tak
# 0.3333333333333333
#
# > thats worth a lot of money gary
# = warte masę forsy
# może całe mnóstwo dzieciaków
# 0.0
#
# > okay
# = w porządku
# okay
# 0.0
#
# > im certain boss
# = całkowicie szefie
# jestem głodna szefie
# 0.3333333333333333
#
# > i didnt know who else to call
# = nie wiedziałem do kogo zadzwonić
# nie wiedziałam dzisiaj chciałem zadzwonić do mnie dzwonił
# 0.375
#
# > major you okay
# = w porządku major
# ojcze
# 0.0
#
# > rules are meant to be broken on occasions
# = czasem można złamać zasady
# zasady ciastka się zdarzyło przed śmiercią
# 0.16666666666666666
#
# > here little guy i need your help
# = jesteś mi potrzebny
# potrzebuje dzieciaków potrzebuje
# 0.0
#
# > doctor
# = doktor
# doktorze
# 0.0
#
# > no thanks
# = nie dzięki
# nie dzięki
# 1.0
#
# > having regard to the treaty establishing the european community
# = uwzględniając traktat ustanawiający wspólnotę europejską
# uwzględniając traktat ustanawiający wspólnotę europejską
# 1.0
#
# > okay ill see you tomorrow
# = ok do jutra
# w razie jutro o
# 0.0
#
# > hey
# = czy ty
# ej
# 0.0
#
# > shit
# = cholera
# cholera
# 1.0
#
# > i love you long
# = kocham cię od dawna
# mam też tak długo
# 0.0
#
# > and i was thinking to myself
# = pomyślałam sobie
# chciałam to osobiście
# 0.0
#
# > people that have power but they want more and more nothing is ever enough for them
# = ludzie którzy maja władzę ale chcą jej coraz więcej oni nigdy nie mają dość
# ludzie robią moc przerwać ale chcą tego więcej nie nic więcej którego nie da a tom mam więcej na
# 0.2631578947368421
#
# > cause youre too cute
# = ponieważ jesteś zbyt ładny
# bo sarah też jesteś uroczy
# 0.2
#
# > maybe not
# = może jednak
# ale nie
# 0.0
#
# > shut the door
# = zamknij drzwi
# zamknij drzwi
# 1.0
#
# > does she work there
# = tam pracuje
# tam pracuje
# 1.0
#
# > i thought it said
# = myślałem że to daje
# myślałem sobie myślałem
# 0.23884377019126307
#
# > please
# = proszę
# proszę
# 1.0
#
# > and they said upstairs that id find you here
# = na górze powiedzieli że cię tu znajdę
# i potrzebują to znaczy że tu jesteśmy
# 0.2857142857142857
#
# > do you know where i can find him
# = nie wiesz gdzie go znajdę
# skąd naprawdę go zgubić
# 0.19470019576785122
#
# > i cant hear my thoughts and i need to hear what im thinking or
# = nie słyszę swoich myśli a chcę wiedzieć o czym myślę
# jest mój wybór i potrzebuję cokolwiek co chciałbym o i jak słyszałam co myśli miałem na myśli ok
# 0.1111111111111111
#
# > late i was asleep
# = późno już spałam
# późno spałem
# 0.3032653298563167
#
# > what run
# = biegiem
# biegnij
# 0.0
#
# > your majesty
# = wasza wysokość
# wasza wysokość
# 1.0
#
# > talked about it some what happened man
# = o co chodzi przyjacielu
# a co dla ciebie co się stało
# 0.14285714285714285
#
# > i shall soon be able to teach you joe
# = niedługo będę mógł cię uczyć joe
# będę cię używam
# 0.24525296078096154
#
# > you look incredible honey
# = wyglądasz niesamowicie
# nie przyjechała jeśli wybierasz jak kutas
# 0.0
#
# > i know his mom
# = znam jego mamę
# jestem przekonany mamo
# 0.0
#
# > prev
# = poprzedni
# rozdział
# 0.0
#
# > dad thinks he knows best about everything
# = ojciec myśli że wszystko wie najlepiej
# tato komandorze myśli
# 0.12262648039048077
#
# > wheres the dean
# = gdzie jest dean
# gdzie jest dean
# 1.0
#
# > guys
# = mówisz poważnie
# panów brata wiem tak
# 0.0
#
# > i brought you something dinner
# = przyniosłam ci obiad
# przyniosłam ci coś
# 0.6666666666666666
#
# > thats not negotiating
# = to nie są negocjacje
# to było brak razy nie
# 0.4
#
# > unlike you two
# = nie tak jak wy
# w przeciwieństwie do żydów
# 0.0
#
# > theres no proof at all
# = nie ma żadnych dowodów
# niepotrzebnie to nie możemy
# 0.25
#
# > hold on a second wait a second
# = chwila chwila
# zaczekaj chwilę przerwy
# 0.0
#
# > you idiot
# = idioto
# ty idioto
# 0.5
#
# > all right lads
# = dobra chłopaki
# w porządku chłopaki
# 0.3333333333333333
#
# > he heard about it
# = on słyszał
# och o tym nie
# 0.0
#
# > check your blood sugar frequently
# = należy wówczas często kontrolować stężenie cukru we krwi
# jutro jest poziom glukozy sprzed informacji
# 0.0
#
# > well sir it took me years to locate that bird but i did
# = tak szukałem go lat ale w końcu znalazłem
# co ze mnie nadszedł poważny wózek porno lub za to widział
# 0.0
#
# > and you think he needs to come quickly
# = i myślisz że powinien szybko przyjechać
# a jak sobie musi się szybko przyjechać
# 0.2857142857142857
#
# > god knows i dont need two of you but he will actually help you
# = bóg jeden wie że nie potrzeba mi was dwóch ale on ci pomoże
# to nie chcesz dwóch was ale nie znajdą ani
# 0.28496906152442425
#
# > she didnt die here either
# = i nawet tu nie zginęła
# umarła jej też ukryte prawda
# 0.0
#
# > everything is under control
# = wszystko pod kontrolą
# wszystko co to właściwy pokój
# 0.2
#
# > well could we maybe just talk inside
# = cóż możemy porozmawiać w środku
# możemy porozmawiać
# 0.22313016014842982
#
# > regulation as last amended by regulation ec no oj l p
# = rozporządzenie ostatnio zmienione rozporządzeniem we nr dzu l z str
# rozporządzenie ostatnio zmienione rozporządzeniem we nr roku ma
# 0.5841005873035536
#
# > date of first authorisation renewal of the authorisation
# = data wydania pierwszego pozwolenia na dopuszczenie do obrotu data przedłużenia terminu ważności pozwolenia na dopuszczenie do obrotu
# data wydania pierwszego pozwolenia na dopuszczenie do obrotu data przedłużenia pozwolenia
# 0.5795782787848095
#
# > it can even be about people i dont know
# = może być nawet o ludziach których nie znam
# tego chciałaś być w wielu w ogóle nie wiemy
# 0.2222222222222222
#
# > great thanks
# = świetnie dzięki
# życzę powodzenia
# 0.0
#
# > thats enough
# = wystarczy
# dosyć
# 0.0
#
# > whats my role in this family who am i who
# = jaka jest moja rola w tej rodzinie
# to nie zrobiłem do tej mnie już dla mnie jest ważne co jest moja ulubiona historia to samo kto
# 0.15789473684210525
#
# > tell her tom called you know what im saying
# = przekaż jej że dzwonił tom wiesz co mówię
# powiedz jej powiedz żebyś chciała na myśli i twoje lat że chodzi
# 0.16666666666666666
#
# > come on
# = no weź
# no dalej
# 0.5
#
# > yes my lord
# = tak panie
# gratuluję
# 0.0
#
# > okay an idea for a movie
# = no dobra pomysł na film
# dobry pomysł
# 0.11156508007421491
#
# > maybe it was fate
# = zabierz ją z naszych rąk
# może właśnie o pieniądze
# 0.0
#
# > you were supposed to go home
# = miałaś jechać do domu
# miałeś chodzić dla domu
# 0.25
#
# > and you doctor
# = a ty doktorze
# a tobie pani doktor
# 0.25
#
# > and this belongs to us
# = i to należy do nas
# to ten wybuch powinniśmy
# 0.19470019576785122
#
# > oh your face
# = twoja twarz
# och twarz nie zwrot
# 0.25
#
# > huh
# = huh
# prawda
# 0.0
#
# > lets go
# = gramy
# już
# 0.0
#
# > what
# = co
# co
# 1.0
#
# > article
# = artykuł
# artykuł
# 1.0
#
# > thats a stupid reason
# = to głupi powód
# to była głupia powód
# 0.5
#
# > go home to your wife
# = wracaj do żony do domu
# idź spać w mojej swojej żoną
# 0.0
#
# > well because they take really good care of him there you know
# = bo dobrze się tam nim zajmują
# bo nas wszystkich wszystko tam się
# 0.5
#
# > i didnt say that
# = nie powiedziałem tego
# nic za to tego
# 0.25
#
# > are those the ground beef flavor
# = te o smaku wołowiny
# są ważne zaczyna się zajmuje to trochę dziwnie
# 0.0
#
# > ill be outside
# = będę na zewnątrz
# będę będę na zewnątrz
# 0.75
#
# > arent you sweetie
# = prawda słonko
# nie kochany kochanie
# 0.0
#
# > you should get some
# = powinnaś jakieś kupić
# powinieneś pozbyć
# 0.0
#
# > yeah did your doctor take you off the meds
# = doktor ci kazał
# twój test
# 0.0
#
# > why marshall
# = dlaczego
# po co byśmy poszli
# 0.0
#
# > she came
# = napisał pan do niej prawda
# dzwoniła po prostu
# 0.0
#
# > oj l p
# = dzu l z s
# dzu l z str
# 0.75
#
# > you sure
# = na pewno
# jesteś pewny
# 0.0
#
# > no fuck that denny
# = pierdol to denny
# daj spokój denny
# 0.3333333333333333
#
# > i dont believe this
# = nie wierzę
# nie wierzę w tej gry
# 0.4
#
# > im not up to go to no meetings or anything
# = nie chce mi się chodzić na spotkania czy coś w tym stylu
# nie jestem na dół w drodze do końca swojego co w
# 0.24902746807698065
#
# > you know well how it is out there
# = dobrze wiesz jak tu jest
# no wiesz jaka za jak tam jest za tu
# 0.4444444444444444
#
# > dad
# = tato
# tato
# 1.0
#
# > who want to know
# = a kto chce wiedzieć
# john kogo wie
# 0.0
#
# > yeah well me too
# = tak no więc ja też
# ja też
# 0.22313016014842982
#
# > oh my brooke
# = och moja brooke
# oh
# 0.0
#
# > at least you lot are here
# = ważne że wy jesteście
# musisz przynajmniej ty tutaj
# 0.0
#
# > okay
# = dobrze
# dobrze
# 1.0
#
# > escaping
# = no tak
# zgoda
# 0.0
#
# > youre lying
# = kłamiesz
# kłamiesz
# 1.0
#
# > this way
# = tutaj
# tędy
# 0.0
#
# > the captain cant save you now
# = teraz już ci kapitan nie pomoże
# kapitanie nie może cię gdzieś pani teraz zadzwonić
# 0.25
#
# > get out of here warn them
# = uciekać stąd ostrzec ich
# wynoś się tu
# 0.0
#
# > why because im a woman or because i got the position too quickly
# = bo jestem kobietą czy dlatego że za szybko dostałam to stanowisko
# bo to ja tylko miałbym wojna pewnie pozycję i chodź operacyjnego na odwrót bo mam chronić ręce jedzie w
# 0.10526315789473684
#
# > unless i locate her huh
# = chyba że ją znajdę co
# chyba tak ją
# 0.3422780793550613
#
# > regulation eec no is hereby repealed with effect from july
# = rozporządzenie ewg nr traci moc ze skutkiem od dnia lipca r
# rozporządzenie ewg nr ewg nr z dnia lipca r
# 0.5338249352778719
#
# > put it back
# = odłóż to
# włóż go
# 0.0
#
# > only he doesnt know that
# = tyle że o tym nie wie
# tylko on nie tego o tym
# 0.5
#
# > he was supposed to be going to london for a conference
# = miał lecieć do londynu na konferencję
# miał odpoczynku tego dla ciebie zegar
# 0.16666666666666666
#
# > next time you have a job pick someone else
# = następnym razem jak będziesz miał robotę wybierz kogoś innego
# następnym razem będzie musiał zarobić twoją kimś rodzina
# 0.22062422564614886
#
# > lonely wow
# = samotnie
# pewnie uciekł
# 0.0
#
# > she likes it very much
# = bardzo jej się podoba
# naprawdę lubi tak bardzo
# 0.25
#
# > you sleep here
# = będziesz spał tutaj
# będziesz spać
# 0.3032653298563167
#
# > i cant feel it
# = nie czuję
# nie czuję
# 1.0
#
# > do you think it matters
# = myślisz że to ma znaczenie
# myślisz że należy się należy
# 0.4
#
# > both no
# = nie
# nie jest nie hej
# 0.25
#
# > youre going to steal them
# = chcesz je ukraść
# wychodzisz swoje stronie
# 0.0
#
# > im coming
# = idę
# już idę
# 0.5
#
# > i didnt know how you felt about her
# = nie wiedziałem co do niej czujesz
# nie wiedziałem jak na pewno będziesz miała w niej
# 0.3333333333333333
#
# > new case
# = nowa sprawa
# new nowa huh
# 0.3333333333333333
#
# > how is she
# = jaka ona jest
# jak jest
# 0.3032653298563167
#
# > we dont know that
# = wcale tego nie wiecie
# nie wiemy
# 0.18393972058572117
#
# > big fella isnt he
# = duży koleś czyż nie
# wiem o tobie też nie ma
# 0.16666666666666666
#
# > shes right there
# = stoi tam
# jest tam
# 0.5
#
# > not even noon
# = nie ma jeszcze południa
# nie jako plany
# 0.23884377019126307
#
# > article
# = artykuł
# artykuł
# 1.0
#
# > i havent seen him for years
# = nie widziałem go od lat
# nie widziałem go za lat
# 0.8
#
# > thank you
# = dziękuje
# dziękuję bardzo
# 0.0
#
# > oh is david going to be here
# = david tu będzie
# david będziemy tu kiedy jesteś
# 0.4
#
# > i help her a little bit i can
# = pomagam jej trochę jak tylko mogę
# pomóż mi się mam
# 0.0
#
# > no come on
# = całkiem dobrze
# no dalej dalej
# 0.0
#
# > you dont need to do this
# = wiesz że nie musisz tego robić
# nie musisz tego robić
# 0.6065306597126334
#
# > i have to
# = muszę
# muszę
# 1.0
#
# > i want to make this work
# = chcę żeby nam wyszło
# chcę wtedy ci się do roboty
# 0.16666666666666666
#
# > the view is over this way im sorry its beautiful up here
# = powinnaś patrzeć w tę stronę
# jest nie jest sposób prowadzi to tutaj
# 0.0
#
# > youre one of the few people in a position to really swing the debate
# = jesteś jedną z niewielu osób które mogą naprawdę prowadzić debatę
# jeden z kimś innym się od energii
# 0.09306272250443651
#
# > you cant escape me
# = nie może mi uciec
# nie można mnie zranić
# 0.25
#
# > i need support i need a man beside me
# = potrzebuje wsparcia potrzebuję mężczyzny u boku
# potrzebna mi uczę to do mnie
# 0.0
#
# > you really do look like her
# = jesteś do niej podobna
# naprawdę my tak naprawdę ją tak
# 0.0
#
# > nothing
# = nic
# nic
# 1.0
#
# > legal basis
# = podstawa prawna
# podstawa prawna danych
# 0.6666666666666666
#
# > he can run
# = on może biegać
# ucieka
# 0.0
#
# > i couldnt do what actually i could do what they do and i think they knew it back then
# = ja nie mógłbym właściwie mógłbym robić to co oni i oni chyba wtedy o tym wiedzieli
# mogło zrobić co robi co zrobimy w tym co zrobić coś jak ona więc jedźmy
# 0.12473426467088237
#
# > its too late for that
# = jest na to za późno
# już za późno na to
# 0.8
#
# > thats what makes me who i am
# = dlatego jestem kim jestem
# właśnie powiedziała mnie sorry
# 0.0
#
# > this place is really cool
# = to miejsce jest świetne
# są tu jest naprawdę super
# 0.2
#
# > him who
# = kto
# kogo
# 0.0
#
# > otherwise she was gonna leave
# = inaczej by odeszła
# inni że już wyszła z siebie
# 0.0
#
# > no thats never been a problem for me
# = nie to nigdy nie było dla mnie problemem
# ani już nie byłaś taki problem
# 0.11942188509563154
#
# > he would he would want us to stay strong
# = on chciałby byśmy zostali przy tym
# on nas chciał być zazdrosny
# 0.1637461506155964
#
# > this piece
# = ten kawałek
# tak do niego
# 0.0
#
# > after a good sleep you feel
# = pani dostaje dobrą wizytę
# a więc dobrze ty nic ci trzeba się
# 0.0
#
# > when soon in the morning
# = kiedy przyjdzie
# kiedy wraca do pana
# 0.25
#
# > uh no one more thing
# = jeszcze jedno
# nikt jeszcze jedno
# 0.6666666666666666
#
# > these look like good seats
# = wydaje się że to dobre miejsca
# wyglądają na emeryturę
# 0.0
#
# > im sorry
# = wiem mamo
# przykro mi
# 0.0
#
# > and steve doesnt like to hear the word no
# = a steve nie lubi słyszeć nie
# steve steve nie lubi żeby tu mówić
# 0.42857142857142855
#
# > no im just kind of playing it by ear
# = tak naprawdę dopiero zaczynam
# ja go tylko ok dobrze
# 0.0
#
# > rare
# = rzadko
# rzadko
# 1.0
#
# > anybody in particular that she was close to
# = była blisko z kimś szczególnym
# kto jest to żeby się pilnować
# 0.0
#
# > i want my own baby
# = chcę mieć własne dziecko
# chcę moje dziecko
# 0.47768754038252614
#
# > yeah
# = tak
# tak
# 1.0
#
# > youre right
# = masz rację
# masz rację
# 1.0
#
# > that wasnt me
# = to nie mój głos
# to nie byłem
# 0.47768754038252614
#
# > well naomi whatever it is im sure wed be happy to help
# = cokolwiek by to nie było chętnie ci pomożemy
# a kiedy czeka nic mi że zniszczy dziewczynę
# 0.0
#
# > exactly
# = dokładnie
# dokładnie
# 1.0
#
# > then
# = wtedy
# zatem
# 0.0
#
# > ls holly here
# = jest tu holly
# jestem tutaj holly
# 0.3333333333333333
#
# > let me do this please
# = pozwól mi proszę
# sprawdzę wszystko
# 0.0
#
# > shes ill what does she do
# = czym się zajmuje
# właśnie zrobię już wiedziała
# 0.0
#
# > yeah come on over
# = no to chodź
# spróbuj już jestem gotowa
# 0.0
#
# > your confidence leaves me with a strong impression
# = podziwiam twoją pewność siebie
# zastrzel rękę
# 0.0
#
# > any time you want though
# = kiedy tylko zechcesz
# jakiś czas umrzesz
# 0.0
#
# > or worse a man with no past and no future
# = to człowiek bez przeszłości i przyszłości cudownie
# chodzi o nic więcej przyszłość została działań
# 0.0
#
# > i think youre
# = carrie myślę że
# zdaje sobie wyobrażasz
# 0.0
#
# > do you
# = a ty
# jest
# 0.0
#
# > will such a jackass come at all
# = ale czy przyjedzie
# posłuchaj
# 0.0
#
# > theyre all still in my house
# = i nadal są w moim domu a oto moja żona
# wciąż wie wszystkim jeszcze wszystko co mój ty
# 0.0
#
# > i wont tell you
# = nie powiem ci
# nie powiem
# 0.6065306597126334
#
# > why did you call someone else
# = czemu dzwonisz do kogoś innego
# pan wrócił do kogoś innego kimś
# 0.5
#
# > its a place where we are one family
# = to miejsce w którym wszyscy jesteśmy jedną rodziną
# tu są miejsce
# 0.06295853427918728
#
# > no of course i am
# = jasne że nie
# nie nie dam radę
# 0.25
#
# > yes not that i was happy to do it but i did it
# = tak nie żebym był szczególnie zadowolony ale to zrobiłem
# nie że tak podobał ale abym to zrobiłem ale to zrobiłem
# 0.45454545454545453
#
# > i dont get your point
# = nie rozumiem do czego zmierzasz
# nie rozumiem
# 0.22313016014842982
#
# > good job buddy good job okay
# = dobra robota kolego dobra robota
# dobrze bardzo dobre
# 0.0
#
# > really
# = naprawdę
# naprawdę
# 1.0
#
# > i dont know
# = czy ja wiem
# mam na prawdę
# 0.0
#
# > but i couldnt say hi to you
# = ale nie miałem okazji się z tobą przywitać
# ale nie mogłam powiedzieć ci
# 0.21952465443761057
#
# > who was it then if it wasnt you
# = więc kto jeśli nie ty
# wtedy by powiedział mi się że to byl
# 0.0
#
# > no
# = nie
# nie
# 1.0
#
# > thats how you have to fucking deal with him
# = tak z nim trzeba kurwa rozmawiać
# jeśli tego potrzebujesz
# 0.0
#
# > theres no way for me to measure how loud i have to scream
# = nie mam pojęcia jak głośno mam krzyczeć
# jak było przede mną po powrocie za wami świeżego powietrza
# 0.1
#
# > slow down
# = zwolnij
# zwolnij
# 1.0
#
# > ok
# = pa
# ok
# 0.0
#
# > fuck you
# = pieprz się
# pierdol się
# 0.5
#
# > shes beautiful
# = piękna
# tak tylko pięknie
# 0.0
#
# > yeah you didnt look
# = nie widziałaś
# nie wyglądasz
# 0.5
#
# > im a mom
# = jestem matką
# jestem mamą
# 0.5
#
# > you see a task force in there
# = i mówisz że on zna się na tym
# widzicie zewnątrz technicznej w imieniu rady szukam
# 0.0
#
# > what
# = co
# co
# 1.0
#
# > if im there and kind of danger danger comes up then im there
# = jeśli pojawi się jakieś niebezpieczeństwo
# gdybyś i tym duchu że jest niebezpieczna ocean cierpiał
# 0.0
#
# > trying to find out
# = staram sie dowiedzieć
# musiałem pić
# 0.0
#
# > dont touch it im not done
# = nie dotykaj jej nie skończyłam
# nie dotykaj
# 0.22313016014842982
#
# > man
# = stary
# mężczyzna
# 0.0
#
# > revenge
# = zemsta
# zemsta
# 1.0
#
# > fuck
# = kurwa
# pierdol
# 0.0
#
# > ill be here
# = nie chcę przeszkadzać
# chodź tu być
# 0.0
#
# > a new sun rising
# = nowy wschód słońca
# każdej nowa dyrektor
# 0.0
#
# > where are you going
# = dokąd idziesz
# dokąd idziesz
# 1.0
#
# > now get out
# = a teraz wynocha
# dziś wychodzić
# 0.0
#
# > what did he know
# = czego się dowiedział
# o czym on powiedział
# 0.0
#
# > yeah youll have them by tonight
# = może być wieczorem
# tak powiedział
# 0.0
#
# > no sex
# = bez seksu
# nie seks
# 0.0
#
# > yo
# = cześć
# zrobione
# 0.0
#
# > fucking hell carl
# = ja pierdolę carl
# jebany twoje ulicy
# 0.0
#
# > weve uh
# = my
# to
# 0.0
#
# > hi boss
# = cześć szefie
# cześć szefie
# 1.0
#
# > its not too much to ask
# = nie ma o co się zbyt pytać
# nie jest zbyt wiele
# 0.23618327637050734
#
# > whats up
# = jak się macie
# co tam
# 0.0
#
# > goodbye
# = do widzenia
# do widzenia
# 1.0
#
# > shes not my girlfriend
# = nie jest moją dziewczyną
# nie jest moim bratem
# 0.5
#
# > no no no
# = nie nie
# nie przestań
# 0.5
#
# > yes very
# = tak bardzo ładny
# tak
# 0.1353352832366127
#
# > trouble
# = kłopot
# problemy chcesz być dolców
# 0.0
#
# > whats wrong get it out of sight
# = jak możesz tak mówić kochanie
# powiedzmy do roboty
# 0.0
#
# > are you kidding me
# = żartujesz
# żartujesz
# 1.0
#
# > take it easy doctor
# = cholerny idiota spokojnie doktorze
# super wielka lekarz sir
# 0.0
#
# > its not about the money son its about the rules
# = tu nie chodzi o pieniądze synu tu chodzi o zasady
# nie chodzi o pieniądze
# 0.22313016014842982
#
# > well your projection was excellent
# = twój występ był wspaniały
# cóż twoja definicja był doskonały
# 0.2
#
# > and theres only one way i know how to do that
# = i jest tylko jedną drogą wiem jak zrobić to
# słucham więcej nie wiem dobrze
# 0.08986579282344431
#
# > what is it
# = co się stało
# witajcie
# 0.0
#
# > its only a photo
# = to tylko zdjęcie
# to tylko dziecko
# 0.6666666666666666
#
# > this is gonna be great
# = będzie świetnie do zobaczenia
# będzie wielki
# 0.18393972058572117
#
# > who died
# = który zmarł
# umarł
# 0.0
#
# > no
# = nie masz rację
# nie
# 0.1353352832366127
#
# > yeah but
# = ale
# tak ale
# 0.5
#
# > i just wanted not to exist anymore
# = chciałem w ogóle nie istnieć
# chciałem już dłużej o tym
# 0.2
#
# > what have you done
# = co zrobiliście
# zrobiliście co zrobiliście
# 0.6666666666666666
#
# > i
# = wiesz
# zdałem
# 0.0
#
# > i shall not want
# = nie brak mi niczego
# nie chcę
# 0.18393972058572117
#
# > yep
# = tak
# tak
# 1.0
#
# > you know my dad could help hes
# = mój tata może ci pomóc
# wiesz moim ojcem miałam z tym pomoże
# 0.0
#
# > i had a productive day today
# = dziś miałem dobry dzień
# to dzień dzisiaj dzień dziś dobra
# 0.3333333333333333
#
# > would you gimme a break
# = zrobimy przerwę
# dasz ci przerwa
# 0.0
#
# > i seem to be able to help to a certain degree
# = jestem w stanie pomagać do pewnego stopnia
# wolałbym być w innej drugiej stronie zjeść po drodze
# 0.1111111111111111
#
# > what the hell do you know about life and death
# = a co ty niby o tym wiesz
# co dobra bądźmy do mojego życia a śmierci życia
# 0.2222222222222222
#
# > your idea is to pretend it never happened and just forget about it is that it
# = powinna udawać że to się nigdy nie wydarzyło i po prostu o tym zapomnieć
# mam pewność mu do powiedzenia
# 0.0
#
# > didnt even call for backup
# = i to bez wsparcia
# nawet nie dzwoniła
# 0.0
#
# > the scope of the additional duties for the purposes of this annex is determined by the scope of the cn codes as they stand at the time of the adoption of this regulation
# = do celów niniejszego załącznika zakres stosowania dodatkowych ceł określony jest przez zakres kodów cn istniejących w chwili przyjęcia niniejszego rozporządzenia
# zakres prac dla określonych w załączniku została instytucji a ten posiłki przez te pola rachunki na mocy niniejszego rozporządzenia
# 0.2496656526359045
#
# > hey lets walk if a car comes we can get a ride
# = jeśli przyjedzie samochód możesz jechać
# wchodzimy jeśli wrócimy na to była świetna zabawa
# 0.125
#
# > yeah why
# = czemu
# widzisz
# 0.0
#
# > how can you
# = jak
# to może pan miewa
# 0.0
#
# > but wheres mother
# = ale gdzie jest mama
# gdzie była matką matko
# 0.25
#
# > lets hope he doesnt see it
# = oby tego nie zobaczył
# mam nadzieję do roboty nikogo nie widziałam
# 0.14285714285714285
#
# > of february
# = z dnia lutego r
# z dnia lutego r
# 1.0
#
# > nick what do you want
# = nick co chcesz
# co chcesz
# 0.6065306597126334
#
# > get out of here
# = proszę się stąd wynieść
# cholera stąd natychmiast
# 0.23884377019126307
#
# > so this is me
# = tu pracuję
# to mi mnie
# 0.0
#
# > thats her car isnt it
# = przecież tam stoi jej samochód
# samochód jest jej samochodu
# 0.38940039153570244
#
# > one
# = raz
# jednego
# 0.0
#
# > anybody out there
# = czy ktoś mnie słyszy
# szuka tu jest
# 0.0
#
# > congratulations
# = gratulacje
# mój obraz
# 0.0
#
# > okay
# = ok
# dobrze
# 0.0
#
# > i say we move on
# = chodźmy dalej
# hej jak cholera no dalej
# 0.2
#
# > just toys really
# = to tylko zabawki
# tylko amerykańskie zabawki
# 0.6666666666666666
#
# > thats homicide jimmy homicide one
# = to morderstwo z zimną krwią
# weźcie te zapisy podjęcia taśmy
# 0.0
#
# > now go
# = teraz spadaj
# teraz pomoże kochanie
# 0.3333333333333333
#
# > checked your bank
# = sprawdziliśmy konto
# sprawdziłem połączenie
# 0.0
#
# > hey guys check it out
# = hej patrzcie
# słuchajcie dziewczynki
# 0.0
#
# > connor was just
# = connor miał
# connor była tylko
# 0.3333333333333333
#
# > certainly counsel if you want to conflict out
# = nie mogę zrezygnować jestem jedynym który zna sprawę
# tak jeśli chcesz ją pan dobra
# 0.0
#
# > she seemed a nice girl so whod imagine shes a criminal
# = więc jakie przestępstwo mogła popełnić
# znów kobiety miła dziewczyna przeżył
# 0.0
#
# > shall we go
# = idziemy
# idziemy idziemy
# 0.5
#
# > i didnt have time to shop
# = nie miałam czasu na zakupy
# nie miałem czasu żeby zostać
# 0.4
#
# > hey um
# = hej
# prawda
# 0.0
#
# > be cool
# = spokój
# nie będzie
# 0.0
#
# > good thats good
# = dobrze
# super mieć
# 0.0
#
# > article
# = artykuł
# artykuł
# 1.0
#
# > have you been doing this a long time
# = długo pan tu pracuje
# długo czy to robicie
# 0.25
#
# > i have come to take my lady to dinner
# = zabieram swoją panią na kolację
# muszę się zająć się napaść w gazecie ze sobą
# 0.0
#
# > isnt there anything you have to say to me
# = wiem nie chce mi pan czegoś powiedzieć taak
# co ci się sobie rozmawiać
# 0.0
#
# > hello hello hello
# = cześć
# halo
# 0.0
#
# > thats great
# = świetnie
# świetnie
# 1.0
#
# > had to find out for yourself last time too
# = ostatnio też musiałeś sam na to wpaść
# czy się dowiedzieć się dwa czas na zmianę
# 0.125
#
# > can you believe it
# = dasz wiarę co
# możesz w to wierzy
# 0.0
#
# > enjoy it one last crack come on
# = ostatnia próba
# on nasza ostatnia biegać z nas przyjedzie
# 0.14285714285714285
#
# > ii have to go
# = muszę kończyć
# musimy pójść
# 0.0
#
# > jimmys dad
# = ojciec jimmyego
# jimmyego tatusiu
# 0.5
#
# > i have faith in them
# = ufam im
# wiarę mam tu
# 0.0
#
# > please be kind
# = proszę bądź miła
# chyba trochę dobrej windy
# 0.0
#
# > ah there she is
# = tutaj jesteś
# no to ona juz
# 0.0
#
# > ill be up there soon
# = wracam tam niebawem
# zaraz tam gdy niedługo przyjdę
# 0.2
#
# > makes two of us
# = to jest nas dwoje
# czy nas dwóch stron
# 0.25
#
# > okay
# = dobrze
# ok
# 0.0
#
# > however
# = o kurwa jednakże
# oj
# 0.0
#
# > i want you to meet a man come come with me
# = muszę ci coś pokazać
# życzy widzieć drogi chorób
# 0.0
#
# > please tom dont do this
# = proszę tom nie rób tego
# proszę zostaw to nie rób
# 0.6
#
# > that indicates she was alone
# = jedzenie dla jednego co oznacza że była sama
# tylko starsza piosenka
# 0.0
#
# > howd you know i was here
# = skąd wiedziałeś że tu jestem
# skąd wiesz że jestem tu jestem
# 0.6666666666666666
#
# > allison had a stroke
# = byłem w szpitalu
# tato mieliśmy wybór
# 0.0
#
# > wheres terry there
# = gdzie jest terry
# gdzie zniknął
# 0.3032653298563167
#
# > he didnt give me a choice
# = nie dał mi wyboru
# nie mnie nie wina
# 0.25
#
# > im a little
# = jestem malutki
# ja też
# 0.0
#
# > a terrible person
# = okropna osoba
# straszna
# 0.0
#
# > um thats the girl the cop was asking me about
# = um to dziewczyna o którą pytał mnie wcześniej glina
# to jest dziewczyna
# 0.09022352215774179
#
# > so you do remember
# = czyli jednak pamiętasz
# więc to robił
# 0.0
#
# > junior see hes done turned on my instructions
# = widzisz nawet nie słucha moich instrukcji
# widzieliście jakieś akta dla mojej pracy
# 0.0
#
# > no it will be
# = taa na pewno będzie
# nie
# 0.0
#
# > open the gate
# = otworzyć bramę
# otwórz bramę
# 0.5
#
# > no but we have to find out
# = nie ale musimy się tego dowiedzieć
# ale bez tlenu tak powtarzam
# 0.1637461506155964
#
# > and the second girl looked exactly like the first one
# = i ta druga wyglądała dokładnie jak ta pierwsza
# i biedna dziewczyna wyglądał jak pierwszą pierwszą
# 0.24767939992862334
#
# > eat what you want
# = zjedz co chcesz
# jedz czego chcesz
# 0.3333333333333333
#
# > the council of the european communities
# = rada wspólnot europejskich
# rada wspólnot europejskich
# 1.0
#
# > quiet
# = cisza
# cicho
# 0.0
#
# > financial provisions
# = postanowienia finansowe
# przepisy opis
# 0.0
#
# > clinical particulars
# = szczegółowe dane kliniczne
# szczegółowe dane kliniczne
# 1.0
#
# > we should at least take his weapon
# = powinniśmy mu zabrać broń
# powinniśmy zrobić szybko zostawiła syna
# 0.2
#
# > hmm and youre here
# = a ty jesteś tutaj
# i jesteś tutaj
# 0.47768754038252614
#
# > then the rumors we heard on the commerce planet must be true after all
# = więc jednak to co nam powiedziano na planecie handlowej musi być prawdą
# więc okazało się przeżyć przedsiębiorstw środki ograniczyć najbardziej bezpieczeństwem
# 0.07961459006375436
#
# > hes a soldier
# = to żołnierz
# nic dziwnego
# 0.0
#
# > itsits in the past
# = to przeszłość
# może zrobimy
# 0.0
#
# > james we have a problem
# = james mamy problem znaleźliśmy wroga
# james mamy problem
# 0.513417119032592
#
# > captain its me
# = kapitanie to ja
# kapitanie zadowolony to ja
# 0.75
#
# > i really really miss it
# = tęsknię za nim
# naprawdę
# 0.0
#
# > um we are completely completely running out of time
# = w tej chwili absolutnie nie mamy czasu
# zgadzamy się skończył
# 0.0
#
# > you cant
# = nic z tego
# nie masz
# 0.0
#
# > prescription for my condition
# = lekarstwa na moją chorobę
# gdy od mojej obliczenia wybiera
# 0.0
#
# > the following definitions are added in article
# = w art dodaje się definicje w brzmieniu
# następujący następujący ustęp z ppkt ii
# 0.0
#
# > hey sweetheart
# = cześć słońce
# hej kochanie
# 0.0
#
# > ive gotta say good call nate
# = muszę przyznać nieźle nate
# mówię żeby wszystko mogę zrobić dobre nate
# 0.14285714285714285
#
# > the telephone
# = podaj telefon
# telefonie
# 0.0
#
# > what is it
# = co to jest
# co jest
# 0.6065306597126334
#
# > i dont know who knows
# = nie wiem
# nie wiem kto wie na myśli
# 0.3333333333333333
#
# > when will your men start on the church
# = kiedy twoi ludzie zaczną pracę przy kościele
# kiedy będziecie w kościele do kościoła
# 0.28216057496353797
#
# > ill be back soon
# = niedługo wrócę
# wkrótce wracam
# 0.0
#
# > lapd
# = policja
# policja
# 1.0
#
# > want to keep the pack
# = chcesz zatrzymać paczkę
# chcesz pisać
# 0.3032653298563167
#
# > whats the matter between you two al did something happen
# = coś się zdarzyło
# to samo o posiadanie dwóch rzeczy koncert
# 0.0
#
# > he did
# = przeżył
# tak on
# 0.0
#
# > who are you supposed to be
# = kim niby jesteś
# powinnaś zobaczyć
# 0.0
#
# > kill them all
# = nie pozwólcie im uciec
# zabij ich wszystkich
# 0.0
#
# > instead we will work together to make this world a better place for all no matter how many legs
# = a zamiast tego będziemy współpracować żeby uczynić ten świat lepszym miejscem dla każdego nie ważne ile ma nóg
# zamiast tego uda się skończy to coś lepszego miejsce
# 0.08175098692698718
#
# > nice suit
# = ładny garnitur
# niezły garnitur
# 0.5
#
# > you see it here when they come back leaves its mark
# = widać to po nich po powrocie
# zobaczymy jakie będzie trwać
# 0.0
#
# > i dont want this top gun shit
# = nie potrzebuję tego gówna
# wyłącz nie obchodzi te cholerne broń
# 0.16666666666666666
#
# > change your mind
# = zmienił pan zdanie
# zmieniłeś zdanie
# 0.3032653298563167
#
# > all right
# = dobrze
# dobrze
# 1.0
#
# > hows the hand acting
# = jak tam ręka
# super
# 0.0
#
# > thank you
# = dziękuję
# dziękuję
# 1.0
#
# > fine ive got work to do
# = i dobrze mam robotę
# dzięki prawie pracuję
# 0.0
#
# > war
# = wojna
# wojna
# 1.0
#
# > john clears throat so what do you suggest we do
# = to co mamy zrobić
# john gdzie masz ogromne
# 0.0
#
# > sister
# = cześć siostro
# siostro
# 0.36787944117144233
#
# > sir
# = proszę pana
# sir sir
# 0.0
#
# > jesus
# = jezu
# jezu
# 1.0
#
# > oh thank goodness youre safe
# = jakie to szczęście że już jesteś bezpieczny
# chodź dziękuję mistrzu
# 0.0
#
# > anything
# = jakiekolwiek
# niczego
# 0.0
#
# > he told you that
# = powiedział ci to
# powiedział ci to
# 1.0
#
# > sit down
# = usiądź
# siadaj
# 0.0
#
# > im afraid
# = owszem boję się
# boję się
# 0.6065306597126334
#
# > but thats not why i called you over here how many square feet was the uh master she she had asked me
# = ale nie o tym chcę rozmawiać
# dlaczego mam tak jak dało się biorą boże
# 0.0
#
# > were family
# = jesteśmy rodziną
# rodziną
# 0.36787944117144233
#
# > ill get back to you
# = zadzwonię później
# oddzwonię do mnie
# 0.0

# %%
def calculate_ngram_counts(tokens, n):
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return collections.Counter(ngrams)

def calculate_bleu_score(candidate, references, n=4):
    candidate_tokens = candidate.split()
    reference_tokens = [reference.split() for reference in references]

    candidate_ngram_counts = [
        calculate_ngram_counts(candidate_tokens, i) for i in range(1, n+1)
    ]
    reference_ngram_counts = [
        [calculate_ngram_counts(reference_tokens[j], i) for i in range(1, n+1)]
        for j in range(len(references))
    ]

    precisions = []
    for i in range(n):
        matches = sum(
            min(candidate_ngram_counts[i][token], max(
                reference_ngram_counts[j][i][token] for j in range(len(references))
            )) for token in candidate_ngram_counts[i]
        )
        total = sum(candidate_ngram_counts[i].values())
        precision = matches / total if total > 0 else 0
        precisions.append(precision)

    if any(precision == 0 for precision in precisions):
        return 0

    brevity_penalty = min(1, len(candidate_tokens) / min(len(reference) for reference in reference_tokens))

    bleu = math.exp(sum(math.log(precision) for precision in precisions) / n) * brevity_penalty * 100
    return bleu


def calculate_corpus_bleu_score(candidate_corpus, reference_corpus, n=1):
    assert len(candidate_corpus) == len(reference_corpus), "Corpus sizes do not match."

    total_bleu_score = 0.0
    num_sentences = len(candidate_corpus)

    for candidate, references in zip(candidate_corpus, reference_corpus):
        bleu_score = calculate_bleu_score(candidate, references, n)
        total_bleu_score += bleu_score

    corpus_bleu_score = total_bleu_score / num_sentences
    return corpus_bleu_score


corpus_bleu_score = calculate_corpus_bleu_score(candidate_corpus, reference_corpus)
print("Corpus BLEU score:", corpus_bleu_score)
# Out:
# Corpus BLEU score: 27.719681829080493

# %% [markdown]
# # Transformer - self-attention
# https://github.com/wangshusen/DeepLearning/blob/master/Slides/10_Transformer_2.pdf

# %%
# !pip install transformers -q

# %%
import transformers

# %%
input_vocab = dataset.token2idx_inputs
target_vocab = dataset.token2idx_targets
src_pad = torch.tensor(SRC_VOCAB[dataset.padding_token]).to(device)
src_sos = torch.tensor(SRC_VOCAB[dataset.start_token]).to(device)
src_eos = torch.tensor(SRC_VOCAB[dataset.end_token]).to(device)
trg_pad = torch.tensor(TRG_VOCAB[dataset.padding_token]).to(device)
trg_sos = torch.tensor(TRG_VOCAB[dataset.start_token]).to(device)
trg_eos = torch.tensor(TRG_VOCAB[dataset.end_token]).to(device)

# %%
train_loader = train_loader
test_loader = test_loader
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8bf043713c9c> in <cell line: 1>()
# ----> 1 train_loader = train_loader
#       2 test_loader = test_loader
#
# NameError: name 'train_loader' is not defined
